# %% [markdown]
# # TP tutoré : pima(diabète)

# %% [markdown]
# * https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database
# * https://www.datacamp.com/community/tutorials/decision-tree-classification-python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# load dataset
#pima = pd.read_csv("./diabetes.csv" header=None, names=col_names)
pima = pd.read_csv(r"C:\Users\bejao\OneDrive\data\diabetes.csv")
pima
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
#split dataset in features and target variable
# X = pima.drop('Outcome', 1) # Features
# y = pima['Outcome'] # Target variable
# X
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(random_state=42)

# Train Decision Tree Classifer
clf = clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7395833333333334

# %%
from sklearn import tree
plt.figure(figsize = (20, 20))
tree_plot=tree.plot_tree(clf, feature_names=X. columns, max_depth=2, filled=True, class_names=y.unique().astype(str))

# %%
# Pruner l'arbre  (optimiser l'IA)
scores=[]
for max_depth in range(2, 10) : 
    clf=DecisionTreeClassifier(max_depth=max_depth, random_state=42)
    clf.fit(X_train, y_train)
    score=clf.score(X_test, y_test)
    scores.append(score)
scores
# Out:
# [0.7447916666666666,
#  0.7604166666666666,
#  0.7552083333333334,
#  0.7604166666666666,
#  0.7447916666666666,
#  0.7291666666666666,
#  0.734375,
#  0.7395833333333334]

# %%
# Je retiens un decision tree avec comme max_depth = 3
clf=DecisionTreeClassifier(max_depth=3, random_state=42)
clf.fit(X_train, y_train)
clf. predict(X_test) 
score=clf.score(X_test, y_test)
score
# Out:
# 0.7604166666666666

# %%
plt.figure(figsize = (20, 20))
tree_plot=tree.plot_tree(clf, feature_names=X. columns, filled=True, class_names=y.unique().astype(str))

# %%
print(tree.export_text(clf, feature_names=X_train.columns.values.tolist()))
# Out:
# |--- Glucose <= 127.50
# |   |--- Age <= 28.50
# |   |   |--- BMI <= 45.40
# |   |   |   |--- Pregnancies <= 7.50
# |   |   |   |   |--- BMI <= 32.30
# |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.67
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.67
# |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.69
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.69
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- BMI >  32.30
# |   |   |   |   |   |--- BloodPressure <= 22.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- BloodPressure >  22.00
# |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 1.27
# |   |   |   |   |   |   |   |--- BMI <= 38.30
# |   |   |   |   |   |   |   |   |--- BMI <= 37.30
# |   |   |   |   |   |   |   |   |   |--- Glucose <= 106.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Glucose >  106.00
# |   |   |   |   |   |   |   |   |   |   |--- SkinThickness <= 9.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- SkinThickness >  9.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- BMI >  37.30
# |   |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.45
# |   |   |   |   |   |   |   |   |   |   |--- BloodPressure <= 83.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- BloodPressure >  83.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.45
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- BMI >  38.30
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  1.27
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Pregnancies >  7.50
# |   |   |   |   |--- class: 1
# |   |   |--- BMI >  45.40
# |   |   |   |--- Age <= 22.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- Age >  22.50
# |   |   |   |   |--- class: 1
# |   |--- Age >  28.50
# |   |   |--- Glucose <= 99.50
# |   |   |   |--- Glucose <= 22.00
# |   |   |   |   |--- class: 1
# |   |   |   |--- Glucose >  22.00
# |   |   |   |   |--- DiabetesPedigreeFunction <= 1.18
# |   |   |   |   |   |--- Insulin <= 224.00
# |   |   |   |   |   |   |--- Glucose <= 94.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Glucose >  94.50
# |   |   |   |   |   |   |   |--- BMI <= 39.50
# |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.38
# |   |   |   |   |   |   |   |   |   |--- Age <= 30.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Age >  30.50
# |   |   |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.38
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- BMI >  39.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Insulin >  224.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- DiabetesPedigreeFunction >  1.18
# |   |   |   |   |   |--- class: 1
# |   |   |--- Glucose >  99.50
# |   |   |   |--- BMI <= 26.35
# |   |   |   |   |--- BMI <= 10.40
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- BMI >  10.40
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- BMI >  26.35
# |   |   |   |   |--- DiabetesPedigreeFunction <= 0.20
# |   |   |   |   |   |--- BloodPressure <= 15.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- BloodPressure >  15.00
# |   |   |   |   |   |   |--- Glucose <= 102.50
# |   |   |   |   |   |   |   |--- BloodPressure <= 79.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- BloodPressure >  79.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Glucose >  102.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- DiabetesPedigreeFunction >  0.20
# |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.57
# |   |   |   |   |   |   |--- Pregnancies <= 1.50
# |   |   |   |   |   |   |   |--- Glucose <= 113.00
# |   |   |   |   |   |   |   |   |--- BMI <= 36.15
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- BMI >  36.15
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Glucose >  113.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Pregnancies >  1.50
# |   |   |   |   |   |   |   |--- BloodPressure <= 83.00
# |   |   |   |   |   |   |   |   |--- BMI <= 39.25
# |   |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.43
# |   |   |   |   |   |   |   |   |   |   |--- Pregnancies <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Pregnancies >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.43
# |   |   |   |   |   |   |   |   |   |   |--- Glucose <= 106.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- Glucose >  106.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- BMI >  39.25
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- BloodPressure >  83.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.57
# |   |   |   |   |   |   |--- Pregnancies <= 6.50
# |   |   |   |   |   |   |   |--- Insulin <= 120.50
# |   |   |   |   |   |   |   |   |--- Age <= 53.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Age >  53.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Insulin >  120.50
# |   |   |   |   |   |   |   |   |--- SkinThickness <= 42.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- SkinThickness >  42.00
# |   |   |   |   |   |   |   |   |   |--- Glucose <= 115.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Glucose >  115.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Pregnancies >  6.50
# |   |   |   |   |   |   |   |--- class: 1
# |--- Glucose >  127.50
# |   |--- BMI <= 29.95
# |   |   |--- Glucose <= 151.50
# |   |   |   |--- SkinThickness <= 28.50
# |   |   |   |   |--- DiabetesPedigreeFunction <= 0.27
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- DiabetesPedigreeFunction >  0.27
# |   |   |   |   |   |--- Insulin <= 81.00
# |   |   |   |   |   |   |--- BloodPressure <= 79.00
# |   |   |   |   |   |   |   |--- BMI <= 23.45
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- BMI >  23.45
# |   |   |   |   |   |   |   |   |--- Glucose <= 143.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Glucose >  143.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- BloodPressure >  79.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Insulin >  81.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- SkinThickness >  28.50
# |   |   |   |   |--- DiabetesPedigreeFunction <= 0.38
# |   |   |   |   |   |--- Glucose <= 150.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Glucose >  150.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- DiabetesPedigreeFunction >  0.38
# |   |   |   |   |   |--- class: 0
# |   |   |--- Glucose >  151.50
# |   |   |   |--- Age <= 59.00
# |   |   |   |   |--- Age <= 25.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Age >  25.50
# |   |   |   |   |   |--- BMI <= 27.10
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- BMI >  27.10
# |   |   |   |   |   |   |--- BMI <= 29.10
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- BMI >  29.10
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Age >  59.00
# |   |   |   |   |--- class: 0
# |   |--- BMI >  29.95
# |   |   |--- Glucose <= 154.50
# |   |   |   |--- BloodPressure <= 61.00
# |   |   |   |   |--- class: 1
# |   |   |   |--- BloodPressure >  61.00
# |   |   |   |   |--- Age <= 42.50
# |   |   |   |   |   |--- Insulin <= 219.00
# |   |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.72
# |   |   |   |   |   |   |   |--- BMI <= 33.75
# |   |   |   |   |   |   |   |   |--- Insulin <= 157.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Insulin >  157.50
# |   |   |   |   |   |   |   |   |   |--- Pregnancies <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Pregnancies >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- BMI >  33.75
# |   |   |   |   |   |   |   |   |--- BloodPressure <= 85.50
# |   |   |   |   |   |   |   |   |   |--- BloodPressure <= 72.00
# |   |   |   |   |   |   |   |   |   |   |--- Glucose <= 128.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Glucose >  128.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- BloodPressure >  72.00
# |   |   |   |   |   |   |   |   |   |   |--- BMI <= 35.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- BMI >  35.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- BloodPressure >  85.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.72
# |   |   |   |   |   |   |   |--- BloodPressure <= 66.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- BloodPressure >  66.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Insulin >  219.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Age >  42.50
# |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.23
# |   |   |   |   |   |   |--- Age <= 44.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Age >  44.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.23
# |   |   |   |   |   |   |--- Pregnancies <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Pregnancies >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- Glucose >  154.50
# |   |   |   |--- DiabetesPedigreeFunction <= 0.34
# |   |   |   |   |--- SkinThickness <= 6.50
# |   |   |   |   |   |--- Pregnancies <= 9.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Pregnancies >  9.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- SkinThickness >  6.50
# |   |   |   |   |   |--- DiabetesPedigreeFunction <= 0.27
# |   |   |   |   |   |   |--- BMI <= 39.05
# |   |   |   |   |   |   |   |--- Age <= 56.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Age >  56.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- BMI >  39.05
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- DiabetesPedigreeFunction >  0.27
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- DiabetesPedigreeFunction >  0.34
# |   |   |   |   |--- DiabetesPedigreeFunction <= 1.16
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- DiabetesPedigreeFunction >  1.16
# |   |   |   |   |   |--- BloodPressure <= 90.00
# |   |   |   |   |   |   |--- Age <= 54.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Age >  54.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- BloodPressure >  90.00
# |   |   |   |   |   |   |--- class: 0

# %%
n_nodes = clf.tree_.node_count
children_left = clf.tree_.children_left
children_right = clf.tree_.children_right
feature = clf.tree_.feature
threshold = clf.tree_.threshold

# %%
def find_path(node_numb, path, x):
        path.append(node_numb)
        if node_numb == x:
            return True
        left = False
        right = False
        if (children_left[node_numb] !=-1):
            left = find_path(children_left[node_numb], path, x)
        if (children_right[node_numb] !=-1):
            right = find_path(children_right[node_numb], path, x)
        if left or right :
            return True
        path.remove(node_numb)
        return False


def get_rule(path, column_names):
    mask = ''
    for index, node in enumerate(path):
        #We check if we are not in the leaf
        if index!=len(path)-1:
            # Do we go under or over the threshold ?
            if (children_left[node] == path[index+1]):
                mask += "(pima['{}']<= {}) \t ".format(column_names[feature[node]], threshold[node])
            else:
                mask += "(pima['{}']> {}) \t ".format(column_names[feature[node]], threshold[node])
    # We insert the & at the right places
    mask = mask.replace("\t", "&", mask.count("\t") - 1)
    mask = mask.replace("\t", "")
    return mask

# %%
# Leaves
leave_id = clf.apply(X_test)

paths ={}
for leaf in np.unique(leave_id):
    path_leaf = []
    find_path(0, path_leaf, leaf)
    paths[leaf] = np.unique(np.sort(path_leaf))

rules = {}
for key in paths:
    rules[key] = get_rule(paths[key], pima.columns)

# %%
rules
# Out:
# {3: "(pima['Glucose']<= 127.5) & (pima['Age']<= 28.5) & (pima['BMI']<= 45.39999961853027)  ",
#  4: "(pima['Glucose']<= 127.5) & (pima['Age']<= 28.5) & (pima['BMI']> 45.39999961853027)  ",
#  6: "(pima['Glucose']<= 127.5) & (pima['Age']> 28.5) & (pima['Glucose']<= 99.5)  ",
#  7: "(pima['Glucose']<= 127.5) & (pima['Age']> 28.5) & (pima['Glucose']> 99.5)  ",
#  10: "(pima['Glucose']> 127.5) & (pima['BMI']<= 29.949999809265137) & (pima['Glucose']<= 151.5)  ",
#  11: "(pima['Glucose']> 127.5) & (pima['BMI']<= 29.949999809265137) & (pima['Glucose']> 151.5)  ",
#  13: "(pima['Glucose']> 127.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']<= 154.5)  ",
#  14: "(pima['Glucose']> 127.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']> 154.5)  "}

# %%
pd.options.display.max_colwidth = 1000
pd.DataFrame({'rules':pd.Series(rules).sort_index()})
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                            rules
# 7                                                                                                                                                                                                                (pima['Glucose']<= 129.5) & (pima['Age']<= 28.5) & (pima['BMI']<= 45.39999961853027) & (pima['BMI']<= 30.449999809265137) & (pima['Pregnancies']<= 7.5) & (pima['Glucose']<= 128.5) & (pima['DiabetesPedigreeFunction']<= 0.6679999828338623)
# 9                                                                                                                                                                            (pima['Glucose']<= 129.5) & (pima['Age']<= 28.5) & (pima['BMI']<= 45.39999961853027) & (pima['BMI']<= 30.449999809265137) & (pima['Pregnancies']<= 7.5) & (pima['Glucose']<= 128.5) & (pima['DiabetesPedigreeFunction']> 0.6679999828338623) & (pima['BMI']<= 23.550000190734863)
# 10                                                                                                                                                                            (pima['Glucose']<= 129.5) & (pima['Age']<= 28.5) & (pima['BMI']<= 45.39999961853027) & (pima['BMI']<= 30.449999809265137) & (pima['Pregnancies']<= 7.5) & (pima['Glucose']<= 128.5) & (pima['DiabetesPedigreeFunction']> 0.6679999828338623) & (pima['BMI']> 23.550000190734863)
# 18                                                                                                                                                                                (pima['Glucose']<= 129.5) & (pima['Age']<= 28.5) & (pima['BMI']<= 45.39999961853027) & (pima['BMI']> 30.449999809265137) & (pima['DiabetesPedigreeFunction']<= 0.895499974489212) & (pima['BloodPressure']<= 53.0) & (pima['DiabetesPedigreeFunction']<= 0.2639999985694885)
# 20                                                                                                                                                     (pima['Glucose']<= 129.5) & (pima['Age']<= 28.5) & (pima['BMI']<= 45.39999961853027) & (pima['BMI']> 30.449999809265137) & (pima['DiabetesPedigreeFunction']<= 0.895499974489212) & (pima['BloodPressure']<= 53.0) & (pima['DiabetesPedigreeFunction']> 0.2639999985694885) & (pima['Glucose']<= 125.5)
# 27                                                              (pima['Glucose']<= 129.5) & (pima['Age']<= 28.5) & (pima['BMI']<= 45.39999961853027) & (pima['BMI']> 30.449999809265137) & (pima['DiabetesPedigreeFunction']<= 0.895499974489212) & (pima['BloodPressure']> 53.0) & (pima['DiabetesPedigreeFunction']<= 0.7305000126361847) & (pima['Insulin']<= 36.5) & (pima['Insulin']<= 34.0) & (pima['SkinThickness']<= 40.5) & (pima['Glucose']<= 111.5)
# 31   (pima['Glucose']<= 129.5) & (pima['Age']<= 28.5) & (pima['BMI']<= 45.39999961853027) & (pima['BMI']> 30.449999809265137) & (pima['DiabetesPedigreeFunction']<= 0.895499974489212) & (pima['BloodPressure']> 53.0) & (pima['DiabetesPedigreeFunction']<= 0.7305000126361847) & (pima['Insulin']<= 36.5) & (pima['Insulin']<= 34.0) & (pima['SkinThickness']<= 40.5) & (pima['Glucose']> 111.5) & (pima['Glucose']<= 114.0) & (pima['SkinThickness']> 31.0)
# 32                                    (pima['Glucose']<= 129.5) & (pima['Age']<= 28.5) & (pima['BMI']<= 45.39999961853027) & (pima['BMI']> 30.449999809265137) & (pima['DiabetesPedigreeFunction']<= 0.895499974489212) & (pima['BloodPressure']> 53.0) & (pima['DiabetesPedigreeFunction']<= 0.7305000126361847) & (pima['Insulin']<= 36.5) & (pima['Insulin']<= 34.0) & (pima['SkinThickness']<= 40.5) & (pima['Glucose']> 111.5) & (pima['Glucose']> 114.0)
# 37                                                                (pima['Glucose']<= 129.5) & (pima['Age']<= 28.5) & (pima['BMI']<= 45.39999961853027) & (pima['BMI']> 30.449999809265137) & (pima['DiabetesPedigreeFunction']<= 0.895499974489212) & (pima['BloodPressure']> 53.0) & (pima['DiabetesPedigreeFunction']<= 0.7305000126361847) & (pima['Insulin']> 36.5) & (pima['Pregnancies']<= 4.5) & (pima['DiabetesPedigreeFunction']<= 0.651500016450882)
# 40        (pima['Glucose']<= 129.5) & (pima['Age']<= 28.5) & (pima['BMI']<= 45.39999961853027) & (pima['BMI']> 30.449999809265137) & (pima['DiabetesPedigreeFunction']<= 0.895499974489212) & (pima['BloodPressure']> 53.0) & (pima['DiabetesPedigreeFunction']<= 0.7305000126361847) & (pima['Insulin']> 36.5) & (pima['Pregnancies']<= 4.5) & (pima['DiabetesPedigreeFunction']> 0.651500016450882) & (pima['DiabetesPedigreeFunction']> 0.6755000054836273)
# 42                                                               (pima['Glucose']<= 129.5) & (pima['Age']<= 28.5) & (pima['BMI']<= 45.39999961853027) & (pima['BMI']> 30.449999809265137) & (pima['DiabetesPedigreeFunction']<= 0.895499974489212) & (pima['BloodPressure']> 53.0) & (pima['DiabetesPedigreeFunction']<= 0.7305000126361847) & (pima['Insulin']> 36.5) & (pima['Pregnancies']> 4.5) & (pima['DiabetesPedigreeFunction']<= 0.39149999618530273)
# 46                                                                                                                                                  (pima['Glucose']<= 129.5) & (pima['Age']<= 28.5) & (pima['BMI']<= 45.39999961853027) & (pima['BMI']> 30.449999809265137) & (pima['DiabetesPedigreeFunction']<= 0.895499974489212) & (pima['BloodPressure']> 53.0) & (pima['DiabetesPedigreeFunction']> 0.7305000126361847) & (pima['BloodPressure']> 68.0)
# 48                                                                                                                                                                                                                                                 (pima['Glucose']<= 129.5) & (pima['Age']<= 28.5) & (pima['BMI']<= 45.39999961853027) & (pima['BMI']> 30.449999809265137) & (pima['DiabetesPedigreeFunction']> 0.895499974489212) & (pima['Insulin']<= 63.0)
# 49                                                                                                                                                                                                                                                  (pima['Glucose']<= 129.5) & (pima['Age']<= 28.5) & (pima['BMI']<= 45.39999961853027) & (pima['BMI']> 30.449999809265137) & (pima['DiabetesPedigreeFunction']> 0.895499974489212) & (pima['Insulin']> 63.0)
# 56                                                                                                                                                                                                                                                                                                                                     (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']<= 26.199999809265137) & (pima['BMI']> 9.649999618530273)
# 60                                                                                                                                                                                                                                                  (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']<= 0.5629999935626984) & (pima['Glucose']<= 101.5) & (pima['BloodPressure']<= 27.0)
# 62                                                                                                                                                                                                                            (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']<= 0.5629999935626984) & (pima['Glucose']<= 101.5) & (pima['BloodPressure']> 27.0) & (pima['Age']<= 42.5)
# 66                                                                                                                                                                  (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']<= 0.5629999935626984) & (pima['Glucose']<= 101.5) & (pima['BloodPressure']> 27.0) & (pima['Age']> 42.5) & (pima['Glucose']<= 97.5) & (pima['SkinThickness']> 24.0)
# 67                                                                                                                                                                                                   (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']<= 0.5629999935626984) & (pima['Glucose']<= 101.5) & (pima['BloodPressure']> 27.0) & (pima['Age']> 42.5) & (pima['Glucose']> 97.5)
# 72                                                                                           (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']<= 0.5629999935626984) & (pima['Glucose']> 101.5) & (pima['BMI']<= 34.60000038146973) & (pima['DiabetesPedigreeFunction']<= 0.4229999929666519) & (pima['BloodPressure']<= 89.0) & (pima['DiabetesPedigreeFunction']<= 0.1665000021457672)
# 76                              (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']<= 0.5629999935626984) & (pima['Glucose']> 101.5) & (pima['BMI']<= 34.60000038146973) & (pima['DiabetesPedigreeFunction']<= 0.4229999929666519) & (pima['BloodPressure']<= 89.0) & (pima['DiabetesPedigreeFunction']> 0.1665000021457672) & (pima['Pregnancies']<= 7.5) & (pima['BloodPressure']> 55.0)
# 82   (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']<= 0.5629999935626984) & (pima['Glucose']> 101.5) & (pima['BMI']<= 34.60000038146973) & (pima['DiabetesPedigreeFunction']<= 0.4229999929666519) & (pima['BloodPressure']<= 89.0) & (pima['DiabetesPedigreeFunction']> 0.1665000021457672) & (pima['Pregnancies']> 7.5) & (pima['Insulin']<= 104.5) & (pima['BloodPressure']> 67.0)
# 85                                                                                                                                                                                       (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']<= 0.5629999935626984) & (pima['Glucose']> 101.5) & (pima['BMI']<= 34.60000038146973) & (pima['DiabetesPedigreeFunction']> 0.4229999929666519)
# 87                                                                                                                                                                                                                         (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']<= 0.5629999935626984) & (pima['Glucose']> 101.5) & (pima['BMI']> 34.60000038146973) & (pima['BMI']<= 37.75)
# 93                                                                                                    (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']<= 0.5629999935626984) & (pima['Glucose']> 101.5) & (pima['BMI']> 34.60000038146973) & (pima['BMI']> 37.75) & (pima['Glucose']<= 124.0) & (pima['Pregnancies']<= 6.0) & (pima['SkinThickness']> 15.0) & (pima['Insulin']<= 177.5)
# 94                                                                                                     (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']<= 0.5629999935626984) & (pima['Glucose']> 101.5) & (pima['BMI']> 34.60000038146973) & (pima['BMI']> 37.75) & (pima['Glucose']<= 124.0) & (pima['Pregnancies']<= 6.0) & (pima['SkinThickness']> 15.0) & (pima['Insulin']> 177.5)
# 95                                                                                                                                                                 (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']<= 0.5629999935626984) & (pima['Glucose']> 101.5) & (pima['BMI']> 34.60000038146973) & (pima['BMI']> 37.75) & (pima['Glucose']<= 124.0) & (pima['Pregnancies']> 6.0)
# 96                                                                                                                                                                                               (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']<= 0.5629999935626984) & (pima['Glucose']> 101.5) & (pima['BMI']> 34.60000038146973) & (pima['BMI']> 37.75) & (pima['Glucose']> 124.0)
# 98                                                                                                                                                                                                                                                                                     (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']> 0.5629999935626984) & (pima['Glucose']<= 88.0)
# 102                                                                                                                                                                                                   (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']> 0.5629999935626984) & (pima['Glucose']> 88.0) & (pima['Pregnancies']<= 7.5) & (pima['Insulin']<= 137.5) & (pima['BMI']<= 28.75)
# 106                                                                                 (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']> 0.5629999935626984) & (pima['Glucose']> 88.0) & (pima['Pregnancies']<= 7.5) & (pima['Insulin']<= 137.5) & (pima['BMI']> 28.75) & (pima['DiabetesPedigreeFunction']> 0.6815000176429749) & (pima['DiabetesPedigreeFunction']<= 1.0740000009536743)
# 108                                                       (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']> 0.5629999935626984) & (pima['Glucose']> 88.0) & (pima['Pregnancies']<= 7.5) & (pima['Insulin']<= 137.5) & (pima['BMI']> 28.75) & (pima['DiabetesPedigreeFunction']> 0.6815000176429749) & (pima['DiabetesPedigreeFunction']> 1.0740000009536743) & (pima['Insulin']<= 59.5)
# 109                                                        (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']> 0.5629999935626984) & (pima['Glucose']> 88.0) & (pima['Pregnancies']<= 7.5) & (pima['Insulin']<= 137.5) & (pima['BMI']> 28.75) & (pima['DiabetesPedigreeFunction']> 0.6815000176429749) & (pima['DiabetesPedigreeFunction']> 1.0740000009536743) & (pima['Insulin']> 59.5)
# 113                                                                                                                                                                (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']> 0.5629999935626984) & (pima['Glucose']> 88.0) & (pima['Pregnancies']<= 7.5) & (pima['Insulin']> 137.5) & (pima['Insulin']<= 225.0) & (pima['SkinThickness']> 47.5)
# 115                                                                                                                                                                                                                                                        (pima['Glucose']<= 129.5) & (pima['Age']> 28.5) & (pima['BMI']> 26.199999809265137) & (pima['DiabetesPedigreeFunction']> 0.5629999935626984) & (pima['Glucose']> 88.0) & (pima['Pregnancies']> 7.5)
# 118                                                                                                                                                                                                                                                                                                                                                                (pima['Glucose']> 129.5) & (pima['BMI']<= 29.949999809265137) & (pima['Pregnancies']<= 1.5)
# 124                                                                                                                                                                                                           (pima['Glucose']> 129.5) & (pima['BMI']<= 29.949999809265137) & (pima['Pregnancies']> 1.5) & (pima['Glucose']<= 145.5) & (pima['DiabetesPedigreeFunction']> 0.2524999976158142) & (pima['Glucose']<= 140.0) & (pima['BMI']<= 23.449999809265137)
# 129                                                                                                                             (pima['Glucose']> 129.5) & (pima['BMI']<= 29.949999809265137) & (pima['Pregnancies']> 1.5) & (pima['Glucose']<= 145.5) & (pima['DiabetesPedigreeFunction']> 0.2524999976158142) & (pima['Glucose']<= 140.0) & (pima['BMI']> 23.449999809265137) & (pima['DiabetesPedigreeFunction']> 0.4065000116825104) & (pima['Age']> 24.5)
# 130                                                                                                                                                                                                                                                 (pima['Glucose']> 129.5) & (pima['BMI']<= 29.949999809265137) & (pima['Pregnancies']> 1.5) & (pima['Glucose']<= 145.5) & (pima['DiabetesPedigreeFunction']> 0.2524999976158142) & (pima['Glucose']> 140.0)
# 135                                                                                                                                                                                                                                        (pima['Glucose']> 129.5) & (pima['BMI']<= 29.949999809265137) & (pima['Pregnancies']> 1.5) & (pima['Glucose']> 145.5) & (pima['Age']<= 61.0) & (pima['BMI']> 23.09999942779541) & (pima['BMI']<= 27.09999942779541)
# 137                                                                                                                                                                                                                  (pima['Glucose']> 129.5) & (pima['BMI']<= 29.949999809265137) & (pima['Pregnancies']> 1.5) & (pima['Glucose']> 145.5) & (pima['Age']<= 61.0) & (pima['BMI']> 23.09999942779541) & (pima['BMI']> 27.09999942779541) & (pima['Age']<= 34.5)
# 142                                                                                                                                                         (pima['Glucose']> 129.5) & (pima['BMI']<= 29.949999809265137) & (pima['Pregnancies']> 1.5) & (pima['Glucose']> 145.5) & (pima['Age']<= 61.0) & (pima['BMI']> 23.09999942779541) & (pima['BMI']> 27.09999942779541) & (pima['Age']> 34.5) & (pima['DiabetesPedigreeFunction']> 0.25299999862909317)
# 148                                                                                                                                                                                                                                                                               (pima['Glucose']> 129.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']<= 154.5) & (pima['Glucose']<= 152.5) & (pima['Age']<= 30.5) & (pima['BloodPressure']<= 61.0)
# 152                                                                                                                                                                                   (pima['Glucose']> 129.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']<= 154.5) & (pima['Glucose']<= 152.5) & (pima['Age']<= 30.5) & (pima['BloodPressure']> 61.0) & (pima['BMI']<= 41.79999923706055) & (pima['BloodPressure']<= 72.0) & (pima['BMI']<= 33.75)
# 156                                                                                                                                                                                                            (pima['Glucose']> 129.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']<= 154.5) & (pima['Glucose']<= 152.5) & (pima['Age']<= 30.5) & (pima['BloodPressure']> 61.0) & (pima['BMI']<= 41.79999923706055) & (pima['BloodPressure']> 72.0)
# 165                                                                                                                                                                                               (pima['Glucose']> 129.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']<= 154.5) & (pima['Glucose']<= 152.5) & (pima['Age']> 30.5) & (pima['SkinThickness']<= 27.5) & (pima['DiabetesPedigreeFunction']<= 0.4359999895095825) & (pima['Age']<= 40.5)
# 170                                                                                                                 (pima['Glucose']> 129.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']<= 154.5) & (pima['Glucose']<= 152.5) & (pima['Age']> 30.5) & (pima['SkinThickness']<= 27.5) & (pima['DiabetesPedigreeFunction']<= 0.4359999895095825) & (pima['Age']> 40.5) & (pima['Age']> 45.5) & (pima['DiabetesPedigreeFunction']> 0.2175000011920929)
# 172                                                                                                                                                              (pima['Glucose']> 129.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']<= 154.5) & (pima['Glucose']<= 152.5) & (pima['Age']> 30.5) & (pima['SkinThickness']<= 27.5) & (pima['DiabetesPedigreeFunction']> 0.4359999895095825) & (pima['DiabetesPedigreeFunction']<= 1.368499994277954)
# 178                                                                                                                                                                                                                                                 (pima['Glucose']> 129.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']<= 154.5) & (pima['Glucose']<= 152.5) & (pima['Age']> 30.5) & (pima['SkinThickness']> 27.5) & (pima['BloodPressure']> 68.0)
# 179                                                                                                                                                                                                                                                                                                                                        (pima['Glucose']> 129.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']<= 154.5) & (pima['Glucose']> 152.5)
# 185                                                                                                                                           (pima['Glucose']> 129.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']> 154.5) & (pima['Insulin']<= 661.5) & (pima['DiabetesPedigreeFunction']<= 0.34299999475479126) & (pima['BMI']<= 35.29999923706055) & (pima['BMI']<= 34.14999961853027) & (pima['DiabetesPedigreeFunction']<= 0.2814999967813492)
# 187                                                                                  (pima['Glucose']> 129.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']> 154.5) & (pima['Insulin']<= 661.5) & (pima['DiabetesPedigreeFunction']<= 0.34299999475479126) & (pima['BMI']<= 35.29999923706055) & (pima['BMI']<= 34.14999961853027) & (pima['DiabetesPedigreeFunction']> 0.2814999967813492) & (pima['DiabetesPedigreeFunction']<= 0.3135000020265579)
# 191                                                                                                                                                                                                      (pima['Glucose']> 129.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']> 154.5) & (pima['Insulin']<= 661.5) & (pima['DiabetesPedigreeFunction']<= 0.34299999475479126) & (pima['BMI']<= 35.29999923706055) & (pima['BMI']> 34.14999961853027)
# 195                                                                                                                                                    (pima['Glucose']> 129.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']> 154.5) & (pima['Insulin']<= 661.5) & (pima['DiabetesPedigreeFunction']<= 0.34299999475479126) & (pima['BMI']> 35.29999923706055) & (pima['Glucose']<= 157.5) & (pima['DiabetesPedigreeFunction']> 0.18699999898672104)
# 196                                                                                                                                                                                                               (pima['Glucose']> 129.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']> 154.5) & (pima['Insulin']<= 661.5) & (pima['DiabetesPedigreeFunction']<= 0.34299999475479126) & (pima['BMI']> 35.29999923706055) & (pima['Glucose']> 157.5)
# 199                                                                                                                                                                                                         (pima['Glucose']> 129.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']> 154.5) & (pima['Insulin']<= 661.5) & (pima['DiabetesPedigreeFunction']> 0.34299999475479126) & (pima['BMI']<= 45.95000076293945) & (pima['BloodPressure']<= 92.0)
# 204                                                                                                                                                                                                                    (pima['Glucose']> 129.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']> 154.5) & (pima['Insulin']<= 661.5) & (pima['DiabetesPedigreeFunction']> 0.34299999475479126) & (pima['BMI']> 45.95000076293945) & (pima['Age']<= 42.0)
# 206                                                                                                                                                                                                                                                                                                                                         (pima['Glucose']> 129.5) & (pima['BMI']> 29.949999809265137) & (pima['Glucose']> 154.5) & (pima['Insulin']> 661.5)

# %%
#rules = {3: "(pima['Insulin']<= 127.5) & (pima['BloodPressure']<= 26.450000762939453) & (pima['BloodPressure']<= 9.100000381469727)  ",
# 4: "(pima['Insulin']<= 127.5) & (pima['BloodPressure']<= 26.450000762939453) & (pima['BloodPressure']> 9.100000381469727)  ",
# 6: "(pima['Insulin']<= 127.5) & (pima['BloodPressure']> 26.450000762939453) & (pima['SkinThickness']<= 27.5)  ",
# 7: "(pima['Insulin']<= 127.5) & (pima['BloodPressure']> 26.450000762939453) & (pima['SkinThickness']> 27.5)  ",
# 10: "(pima['Insulin']> 127.5) & (pima['BloodPressure']<= 28.149999618530273) & (pima['Insulin']<= 145.5)  ",
# 11: "(pima['Insulin']> 127.5) & (pima['BloodPressure']<= 28.149999618530273) & (pima['Insulin']> 145.5)  ",
# 13: "(pima['Insulin']> 127.5) & (pima['BloodPressure']> 28.149999618530273) & (pima['Insulin']<= 158.5)  ",
# 14: "(pima['Insulin']> 127.5) & (pima['BloodPressure']> 28.149999618530273) & (pima['Insulin']> 158.5)  "}

# %%
pimaCond = pima[eval(rules[7])]

# %%
pimaCond.head()
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3             1       89             66             23       94  28.1
# 27            1       97             66             15      140  23.2
# 32            3       88             58             11       54  24.8
# 33            6       92             92              0        0  19.9
# 47            2       71             70             27        0  28.0
#
#     DiabetesPedigreeFunction  Age  Outcome
# 3                      0.167   21        0
# 27                     0.487   22        0
# 32                     0.267   22        0
# 33                     0.188   28        0
# 47                     0.586   22        0

# %%
pimaCond.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   124.000000  124.000000     124.000000     124.000000  124.000000
# mean      1.879032   95.645161      59.467742      14.508065   38.411290
# std       1.554394   18.821884      22.007551      10.058767   49.199282
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   88.000000      56.000000       0.000000    0.000000
# 50%       1.500000   98.500000      62.000000      16.000000    7.500000
# 75%       3.000000  107.250000      70.000000      22.000000   67.000000
# max       7.000000  128.000000     122.000000      35.000000  265.000000
#
#               BMI  DiabetesPedigreeFunction         Age  Outcome
# count  124.000000                124.000000  124.000000    124.0
# mean    23.482258                  0.315984   23.379032      0.0
# std      6.571929                  0.155949    2.162477      0.0
# min      0.000000                  0.078000   21.000000      0.0
# 25%     21.800000                  0.190750   22.000000      0.0
# 50%     24.750000                  0.286500   23.000000      0.0
# 75%     27.425000                  0.423000   25.000000      0.0
# max     30.400000                  0.666000   28.000000      0.0

# %%
X_front=X_train[['Glucose', 'BMI']].to_numpy()

# %%
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt

tree_front = DecisionTreeClassifier(random_state=42, max_depth=3)
tree_front.fit(X_front, y_train)

# Plotting decision regions
plot_decision_regions(X_front, y_train.to_numpy(), clf=tree_front, legend=2)

# Adding axes annotations
#plt.xlabel('sepal length [cm]')
#plt.ylabel('petal length [cm]')
#plt.title('SVM on Iris')
plt.show()
